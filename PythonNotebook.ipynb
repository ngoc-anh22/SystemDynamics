# %%
print("Hello Python world")
# Out:
# Hello Python world

# %%
print('hello second')
# Out:
# hello second

# %%
print('HHhahahahdjfosj')
# Out:
# HHhahahahdjfosj

# %% [markdown]
# ![GT--mmxaoAAa1_W.jpeg](data:image/jpeg;base64,...)

# %%
a = 'Ngoc'
T = 'Anh'
print(a, T)
# Out:
# Ngoc Anh

# %%
price = {'Eggs':4.5, 'Steak': 25.5, 'Beer': 3.5, 'Bacon': 5.3, 100: 'Discount', 'Milk': [3.5,10]}
print(price['Milk'])
# Out:
# [3.5, 10]

# %%
grades = {1: 'best', 2:'good', 3:'moderate', 4:'bad', 5:'very bad'}
grades[1]
# Out:
# 'best'

# %%
list1 = [10,'NA','SystemDynamics',10, [1,2,3,4,5]]
print(list1[0])
# Out:
# 10

# %%
list1[4][2]
# Out:
# 3

# %% [markdown]
# Numpy

# %%
import numpy as np
array = np.array([[1,2,3,4],[2,4,6,7],[10,20,30,40],[3,42,45,6]])
print(array)
# Out:
# [[ 1  2  3  4]
#  [ 2  4  6  7]
#  [10 20 30 40]
#  [ 3 42 45  6]]

# %% [markdown]
# Data Frame with pandas

# %%
import pandas as pd
df = pd.DataFrame(array,index=['R1','R2','R3','R4'], columns=['C1','C2','C3','C4'])
df2 = pd.DataFrame(array)
print(df2)
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   2   4   6   7
# 2  10  20  30  40
# 3   3  42  45   6

# %%
data = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Housing%20Price%20Index%20Regression/monthly-hpi.csv')
data
# Out:
#           date  housing_price_index
# 0   2010-11-01               186.07
# 1   2010-12-01               183.27
# 2   2011-01-01               181.35
# 3   2011-02-01               179.66
# 4   2011-03-01               178.84
# ..         ...                  ...
# 68  2016-07-01               241.59
# 69  2016-08-01               242.09
# 70  2016-09-01               242.27
# 71  2016-10-01               241.88
# 72  2016-11-01               242.21
#
# [73 rows x 2 columns]

# %%
data2 = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Housing%20Price%20Index%20Regression/monthly-hpi.csv')
data2
# Out:
#           date  housing_price_index
# 0   2010-11-01               186.07
# 1   2010-12-01               183.27
# 2   2011-01-01               181.35
# 3   2011-02-01               179.66
# 4   2011-03-01               178.84
# ..         ...                  ...
# 68  2016-07-01               241.59
# 69  2016-08-01               242.09
# 70  2016-09-01               242.27
# 71  2016-10-01               241.88
# 72  2016-11-01               242.21
#
# [73 rows x 2 columns]

# %% [markdown]
# How to upload files from computer on gg colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd832e2c-67d8-4e66-9404-70991f5ec39d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd832e2c-67d8-4e66-9404-70991f5ec39d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ex = pd.read_csv('bank-loan.csv')
ex
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0     41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1     27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2     40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3     41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4     24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ..   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 845   34   1      12       15      32      2.7   0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7   4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8   0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8   0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9   0.899130  4.389870      NaN
#
# [850 rows x 9 columns]

# %%
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 59.9 KB

# %% [markdown]
# std: độ dài về nhà tìm hiểu thêm

# %%
ex.describe()
# Out:
#               age          ed      employ     address      income     debtinc  \
# count  850.000000  850.000000  850.000000  850.000000  850.000000  850.000000
# mean    35.029412    1.710588    8.565882    8.371765   46.675294   10.171647
# std      8.041432    0.927784    6.777884    6.895016   38.543054    6.719441
# min     20.000000    1.000000    0.000000    0.000000   13.000000    0.100000
# 25%     29.000000    1.000000    3.000000    3.000000   24.000000    5.100000
# 50%     34.000000    1.000000    7.000000    7.000000   35.000000    8.700000
# 75%     41.000000    2.000000   13.000000   12.000000   55.750000   13.800000
# max     56.000000    5.000000   33.000000   34.000000  446.000000   41.300000
#
#          creddebt     othdebt     default
# count  850.000000  850.000000  700.000000
# mean     1.576805    3.078789    0.261429
# std      2.125840    3.398803    0.439727
# min      0.011696    0.045584    0.000000
# 25%      0.382176    1.045942    0.000000
# ...

# %%
ex.head()
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4   24   2       2        0      28     17.3   1.787436  3.056564      1.0

# %%
ex.tail()
# Out:
#      age  ed  employ  address  income  debtinc  creddebt   othdebt  default
# 845   34   1      12       15      32      2.7  0.239328  0.624672      NaN
# 846   32   2      12       11     116      5.7  4.026708  2.585292      NaN
# 847   48   1      13       11      38     10.8  0.722304  3.381696      NaN
# 848   35   2       1       11      24      7.8  0.417456  1.454544      NaN
# 849   37   1      20       13      41     12.9  0.899130  4.389870      NaN

# %%
clean = ex.dropna()
clean
# Out:
#      age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0     41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1     27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2     40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3     41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4     24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ..   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 695   36   2       6       15      27      4.6   0.262062  0.979938      1.0
# 696   29   2       6        4      21     11.5   0.369495  2.045505      0.0
# 697   33   1      15        3      32      7.6   0.491264  1.940736      0.0
# 698   45   1      19       22      77      8.4   2.302608  4.165392      0.0
# 699   37   1      12       14      44     14.7   2.994684  3.473316      0.0
#
# [700 rows x 9 columns]

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 700 entries, 0 to 699
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       700 non-null    int64
#  1   ed        700 non-null    int64
#  2   employ    700 non-null    int64
#  3   address   700 non-null    int64
#  4   income    700 non-null    int64
#  5   debtinc   700 non-null    float64
#  6   creddebt  700 non-null    float64
#  7   othdebt   700 non-null    float64
#  8   default   700 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 54.7 KB

# %%
df
# Out:
#     C1  C2  C3  C4
# R1   1   2   3   4
# R2   2   4   6   7
# R3  10  20  30  40
# R4   3  42  45   6

# %%
df.loc['R1'][:]
# Out:
# C1    1
# C2    2
# C3    3
# C4    4
# Name: R1, dtype: int64

# %%
df.loc['R1'][2]
# Out:
# <ipython-input-23-e3ae487f6469>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc['R1'][2]
# 3

# %%
df.loc['R1','C2'] = 10000
df
# Out:
#     C1     C2  C3  C4
# R1   1  10000   3   4
# R2   2      4   6   7
# R3  10     20  30  40
# R4   3     42  45   6

# %%
df['C3']
# Out:
# R1     3
# R2     6
# R3    30
# R4    45
# Name: C3, dtype: int64

# %%
df['C5'] = [1,2,3,4]
df
# Out:
#     C1     C2  C3  C4  C5
# R1   1  10000   3   4   1
# R2   2      4   6   7   2
# R3  10     20  30  40   3
# R4   3     42  45   6   4

# %%
df.loc['R5'] = [1,2,3,4,5]
df
# Out:
#     C1     C2  C3  C4  C5
# R1   1  10000   3   4   1
# R2   2      4   6   7   2
# R3  10     20  30  40   3
# R4   3     42  45   6   4
# R5   1      2   3   4   5

# %%
df['C5'] = [23,55,66,22,555]
df
# Out:
#     C1     C2  C3  C4   C5
# R1   1  10000   3   4   23
# R2   2      4   6   7   55
# R3  10     20  30  40   66
# R4   3     42  45   6   22
# R5   1      2   3   4  555

# %%
df_drop = df.drop(index='R2',columns='C5')
df_drop
# Out:
#     C1     C2  C3  C4
# R1   1  10000   3   4
# R3  10     20  30  40
# R4   3     42  45   6
# R5   1      2   3   4

# %%
df
# Out:
#     C1     C2  C3  C4   C5
# R1   1  10000   3   4   23
# R2   2      4   6   7   55
# R3  10     20  30  40   66
# R4   3     42  45   6   22
# R5   1      2   3   4  555
